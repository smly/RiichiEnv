# %% [markdown]
# # RiichiEnv Replay Viewer Demo
#
# This notebook demonstrates how to use the standalone Replay Viewer using a sample log provided in the repo.
# The viewer works completely client-side in the browser, meaning you can save this notebook as HTML or view it on NBViewer and the replay will still be interactive.

# %%
from riichienv import RiichiEnv
from riichienv.agents import RandomAgent


agent = RandomAgent()
env = RiichiEnv()
obs_dict = env.reset()
while not env.done():
    actions = {player_id: agent.act(obs)
               for player_id, obs in obs_dict.items()}
    obs_dict = env.step(actions)

scores, points, ranks = env.scores(), env.points(), env.ranks()
print(scores, points, ranks)
# Out:
# [25000, 25000, 25000, 25000] [50, 10, -10, -50] [1, 2, 3, 4]

# %%
from riichienv.visualizer import Replay

Replay.from_list(env.mjai_log)
# Out:
#         <div id="riichienv-viewer-ebbae79f-b079-423a-b283-7292b255b4df" style="width: 100%; min-height: 600px; border: 1px solid #ddd;">
#              <div style="padding: 20px; text-align: center; font-family: sans-serif; color: #666;">
#                 Loading RiichiEnv Replay...
#              </div>
#         </div>
#         <script>
#         (function() {
#             const runViewer = (jsCode) => {
#                 try {
#                     if (jsCode) {
#                         const script = document.createElement('script');
#                         script.text = jsCode;
#                         document.head.appendChild(script);
#                     }
#
#                     const logData = [{"id": 0, "type": "start_game", "meta": {}}, {"bakaze": "E", "dora_marker": "1p", "honba": 0, "kyoku": 1, "kyotaku": 0, "oya": 0, "scores": [25000, 25000, 25000, 25000], "tehais": [["2m", "2m", "4m", "4m", "5m", "8m", "3p", "6p", "9p", "7s", "S", "C", "C"], ["2m", "7m", "2p", "3p", "5p", "7p", "1s", "6s", "7s", "8s", "W", "N", "P"], ["1m", "1m", "7m", "9m", "1p", "7p", "3s", "4s", "8s", "8s", "S", "N", "P"], ["1m", "3m", "8m", "9m", "4p", "5p", "9p", "1s", "3s", "4s", "W", "P", "F"]], "type": "start_kyoku", "meta": {}}, {"actor": 0, "pai": "8m", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "9p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "4p", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "5p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "1s", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "S", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "W", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "P", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "6p", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "8m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "2s", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "P", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "2m", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "7m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "consumed": ["8m", "9m"], "pai": "7m", "target": 2, "type": "chi", "meta": {}}, {"actor": 3, "pai": "W", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "4m", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "4m", "tsumogiri": true, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "4s", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "N", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "6m", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "1m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "F", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "F", "tsumogiri": true, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "4p", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "4p", "tsumogiri": true, "type": "dahai", "meta": {}}, {"actor": 1, "consumed": ["2p", "3p"], "pai": "4p", "target": 0, "type": "chi", "meta": {}}, {"actor": 1, "pai": "1s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "1m", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "8s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "8m", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "4p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "6m", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "5m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "5s", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "7m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "7m", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "3s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "7s", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "1s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "9s", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "2m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "6s", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "2m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "F", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "8s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "6m", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "7s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "5m", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "S", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "3m", "type": "tsumo", "meta": {}}, {"actor": 1, "pai":  ...

# %%
# log_path = '../tools/replay-visualizer/example_log_b124_m244_0.jsonl'
# Replay.from_jsonl(log_path)
