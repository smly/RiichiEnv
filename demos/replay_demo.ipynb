# %% [markdown]
# # RiichiEnv Replay Viewer Demo
#
# This notebook demonstrates how to use the standalone Replay Viewer using a sample log provided in the repo.
# The viewer works completely client-side in the browser, meaning you can save this notebook as HTML or view it on NBViewer and the replay will still be interactive.

# %%
from riichienv import RiichiEnv
from riichienv.visualizer import Replay
from riichienv.agents import RandomAgent


agent = RandomAgent()
env = RiichiEnv(game_mode="4p-red-half")
obs_dict = env.reset()
while not env.done():
    actions = {player_id: agent.act(obs)
               for player_id, obs in obs_dict.items()}
    obs_dict = env.step(actions)

scores, points, ranks = env.scores(), env.points(), env.ranks()
print(scores, points, ranks)
# Out:
# [25000, 25000, 25000, 25000] [50, 10, -10, -50] [1, 2, 3, 4]

# %%
Replay.from_list(env.mjai_log)
# Out:
#         <div id="riichienv-viewer-4907f0ca-5f7c-43cb-befa-ce8d44267740" style="width: 100%; min-height: 600px; border: 1px solid #ddd; box-sizing: border-box;">
#              <div style="padding: 20px; text-align: center; font-family: sans-serif; color: #666;">
#                 Loading RiichiEnv Replay...
#              </div>
#         </div>
#         <script>
#         (function() {
#             const expectedHash = "170cfefe38620ae37fd25cb8f216e855";
#
#             const runViewer = (jsCode) => {
#                 try {
#                     if (jsCode) {
#                         const script = document.createElement('script');
#                         script.text = jsCode;
#                         document.head.appendChild(script);
#                         // Store the hash after loading new code
#                         window.RiichiEnvViewerHash = expectedHash;
#                     }
#
#                     const logData = [{"id": 0, "type": "start_game", "meta": {}}, {"bakaze": "E", "dora_marker": "3s", "honba": 0, "kyoku": 1, "kyotaku": 0, "oya": 0, "scores": [25000, 25000, 25000, 25000], "tehais": [["1m", "2m", "4m", "4m", "6m", "7m", "1p", "2p", "4p", "9p", "6s", "9s", "S"], ["6m", "1p", "1p", "8p", "9p", "1s", "1s", "2s", "3s", "5s", "6s", "7s", "N"], ["2m", "5m", "8m", "4p", "4s", "5s", "8s", "8s", "9s", "N", "N", "P", "F"], ["4m", "6m", "9m", "3p", "7p", "1s", "1s", "3s", "4s", "7s", "9s", "P", "F"]], "type": "start_kyoku", "meta": {}}, {"actor": 0, "pai": "5p", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "6m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "8p", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "6m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "2p", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "F", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "4m", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "1s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "5pr", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "6s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "consumed": ["5s", "7s"], "pai": "6s", "target": 0, "type": "chi", "meta": {}}, {"actor": 1, "pai": "2s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "E", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "2p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "8s", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "6m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "5m", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "5m", "tsumogiri": true, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "E", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "6s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "C", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "E", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "8p", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "4m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "consumed": ["4m", "4m"], "pai": "4m", "target": 3, "type": "pon", "meta": {}}, {"actor": 0, "pai": "1m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "8m", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "3s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "7p", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "4p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "N", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "4s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "W", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "9s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "7m", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "8m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "2p", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "2m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "E", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "9m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "5m", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "5p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "P", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "8p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "9m", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "N", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "5sr", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "5sr", "tsumogiri": true, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "1m", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "1m", "tsumogiri": true, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "F", "type": "tsumo", "meta": {}}, {"actor": 1, " ...

# %%
# log_path = '../tools/replay-visualizer/example_log_b124_m244_0.jsonl'
# Replay.from_jsonl(log_path)
